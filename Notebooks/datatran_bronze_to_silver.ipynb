-- %%
CREATE OR REPLACE TABLE workspace.projeto_datatran.datatran_silver AS
SELECT 
    id,
    to_date(data_inversa, 'yyyy-MM-dd') AS data,
    dia_semana,
    try_to_timestamp(horario, 'yyyy-MM-dd HH:mm:ss') AS horario,
    uf,
    br,
    km,
    municipio,
    causa_acidente,
    tipo_acidente,
    classificacao_acidente,
    fase_dia,
    sentido_via,
    condicao_metereologica,
    tipo_pista,
    tracado_via,
    uso_solo,
    ano,
    try_cast(pessoas AS INT) AS pessoas,
    try_cast(mortos AS INT) AS mortos,
    try_cast(feridos_leves AS INT) AS feridos_leves,
    try_cast(feridos_graves AS INT) AS feridos_graves,
    try_cast(ilesos AS INT) AS ilesos,
    try_cast(ignorados AS INT) AS ignorados,
    try_cast(feridos AS INT) AS feridos,
    try_cast(veiculos AS INT) AS veiculos,
    latitude,
    longitude,
    regional,
    delegacia,
    uop,
    pesid,
    causa_principal,
    ordem_tipo_acidente,
    id_veiculo,
    tipo_veiculo,
    marca,
    ano_fabricacao_veiculo,
    tipo_envolvido,
    estado_fisico,
    idade,
    sexo 
FROM workspace.projeto_datatran.datatran_bronze;
